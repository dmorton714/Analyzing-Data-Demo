# %%
import pandas as pd

# %% [markdown]
# Link to the data set used: https://www.kaggle.com/datasets/thedevastator/global-video-game-sales-ratings?resource=download
#
# ## Importing our CSV file

# %%
df = pd.read_csv('Raw Data.csv')

# %% [markdown]
# <h3> Printing our first few rows to get a look at the data </h3>
# use the df.head() function to see the first bit of the sheet.

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %% [markdown]
# Lets see the shape of the data frame and use the df.shape method.
# <br>
# Doc: https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.shape.html

# %%
df.shape
# Out:
# (16719, 16)

# %% [markdown]
# Here we want to get an idea of whats in our data frame, objects, floats, ect.
# <br>
# The info() method prints information about the DataFrame.
#
# info() documentation : https://www.w3schools.com/python/pandas/ref_df_info.asp#:~:text=The%20info()%20method%20prints,method%20actually%20prints%20the%20info.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %% [markdown]
# List the columns to get an idea of what to sort by.
# <br>
# Column name doc : https://sparkbyexamples.com/pandas/pandas-get-column-names/

# %%
list(df.columns)
# Out:
# ['Name',
#  'Platform',
#  'Year_of_Release',
#  'Genre',
#  'Publisher',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales',
#  'Critic_Score',
#  'Critic_Count',
#  'User_Score',
#  'User_Count',
#  'Developer',
#  'Rating']

# %% [markdown]
# Sort the data by NA_Sales.
# <br>
# Use the ascending and inplace argumants.
# <br>
# Pandas sort doc : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html

# %%
df.sort_values(by='NA_Sales', ascending=False, inplace=True)
df.head()
# Out:
#                 Name Platform  Year_of_Release     Genre Publisher  NA_Sales  \
# 0         Wii Sports      Wii           2006.0    Sports  Nintendo     41.36
# 1  Super Mario Bros.      NES           1985.0  Platform  Nintendo     29.08
# 9          Duck Hunt      NES           1984.0   Shooter  Nintendo     26.93
# 5             Tetris       GB           1989.0    Puzzle  Nintendo     23.20
# 2     Mario Kart Wii      Wii           2008.0    Racing  Nintendo     15.68
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# 0     28.96      3.77         8.45         82.53          76.0          51.0
# 1      3.58      6.81         0.77         40.24           NaN           NaN
# 9      0.63      0.28         0.47         28.31           NaN           NaN
# 5      2.26      4.22         0.58         30.26           NaN           NaN
# 2     12.76      3.79         3.29         35.52          82.0          73.0
#
#   User_Score  User_Count Developer Rating
# 0          8       322.0  Nintendo      E
# 1        NaN         NaN       NaN    NaN
# 9        NaN         NaN       NaN    NaN
# 5        NaN         NaN       NaN    NaN
# 2        8.3       709.0  Nintendo      E

# %% [markdown]
# Use the .unique() method to find unique values in the Platform Col.
#
# doc : https://www.geeksforgeeks.org/python-pandas-series-unique/

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'X360', 'SNES', 'DS', 'PS2', '2600', 'PS3',
#        'N64', 'XB', 'GBA', 'PS4', '3DS', 'XOne', 'GEN', 'GC', 'PC', 'PS',
#        'WiiU', 'PSP', 'DC', 'SCD', 'PSV', 'SAT', 'WS', '3DO', 'NG',
#        'TG16', 'PCFX', 'GG'], dtype=object)

# %% [markdown]
# Use the value counts methods to count the publishers Column
# <br>
# Assign this to df2
# <br>
# Doc: https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html

# %%
df2 = df['Publisher'].value_counts()
df2.head(20)
# Out:
# Electronic Arts                           1356
# Activision                                 985
# Namco Bandai Games                         939
# Ubisoft                                    933
# Konami Digital Entertainment               834
# THQ                                        715
# Nintendo                                   706
# Sony Computer Entertainment                687
# Sega                                       638
# Take-Two Interactive                       422
# Capcom                                     386
# Atari                                      367
# Tecmo Koei                                 348
# Warner Bros. Interactive Entertainment     235
# Square Enix                                234
# Disney Interactive Studios                 218
# Unknown                                    201
# Eidos Interactive                          198
# Midway Games                               198
# 505 Games                                  191
# Name: Publisher, dtype: int64

# %% [markdown]
# <h3> Here we will uses some querys to answer questions </h3>
# What us a Query:
# A query can give you an answer to a simple question, perform calculations, combine data from different tables, add, change, or delete data from a database. Since queries are so versatile, there are many types of queries and you would create a type of query based on the task.
# <br>
# <br>
# Lets find the Nintendo games that have a critic score of 90 or better.
# <br>
# <br>
# Doc : https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %% [markdown]
# query the publisher col and drop non-nintendo values
# <br>
# query the critic scores over 90
# <br>
# sort the remaining DF to by critic score
# <br>
# print the top 20 rows

# %%
df = df.query('Publisher == "Nintendo"').dropna()
df = df.query('Critic_Score > 90')
df.sort_values(by='Critic_Score', ascending=False, inplace=True)
df.head(20)
# Out:
#                                          Name Platform  Year_of_Release  \
# 49                         Super Mario Galaxy      Wii           2007.0
# 97                       Super Mario Galaxy 2      Wii           2010.0
# 517                             Metroid Prime       GC           2002.0
# 233       The Legend of Zelda: The Wind Waker       GC           2002.0
# 1162   The Legend of Zelda: Twilight Princess       GC           2006.0
# 553   The Legend of Zelda: A Link to the Past      GBA           2002.0
# 107    The Legend of Zelda: Twilight Princess      Wii           2006.0
# 166                 Mario Kart: Super Circuit      GBA           2001.0
# 260                      Super Mario 3D World     WiiU           2013.0
# 306        The Legend of Zelda: Skyward Sword      Wii           2011.0
# 39                    Super Smash Bros. Brawl      Wii           2008.0
# 848                    Fire Emblem: Awakening      3DS           2012.0
# 4446       Eternal Darkness: Sanity's Requiem       GC           2002.0
# 2275                     Xenoblade Chronicles      Wii           2010.0
# 2919                             Advance Wars      GBA           2001.0
# 1474                  Metroid Prime 2: Echoes       GC           2004.0
# 6118                 Final Fantasy VI Advance      GBA           2006.0
# 1081                           Metroid Fusion      GBA           2002.0
# 136                      Super Mario Sunshine       GC           2002.0
# 111                   Super Smash Bros. Melee       GC           2001.0
#
#              Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 49        Platform  Nintendo      6.06      3.35      1.20         0.74
# 97        Platform  Nintendo      3.56      2.35      0.98         0.62
# 517        Shooter  Nintendo      1.96      0.67      0.10         0.09
# 233         Action  Nintendo      2.60      0.99      0.89         0.13
# 1162        Action  Nintendo      1.15      0.36      0.04         0.04
# 553         Action  Nintendo      1.75      0.52      0.33         0.10
# 107         Action  Nintendo      3.74      2.14      0.60         0.68
# 166         Racing  Nintendo      2.62      1.64      0.99         0.23
# 260       Platform  Nintendo      2.11      1.16      0.73         0.32
# 306         Action  Nintendo      2.03      1.16      0.37         0.38
# 39        Fighting  Nintendo      6.62      2.55      2.66         1.01
# 848   Role-Playing  Nintendo      0.90      0.45      0.54         0.13
# 4446     Adventure  Nintendo      0.34      0.09      0.00         0.01
# 2275  Role-Playing  Nintendo      0.43      0.25      0.16         0.07
# 2919      Strategy  Nintendo      0.50      0.19      0.00         0.01
# 1474       Shooter  Nintendo      0.87      0.35      0.07         0.04
# 6118  Role-Playing  Nintendo      0.00      0.00      0.28         0.01
# 1081        Action  Nintendo      1.18      0.27      0.17         0.06
# 136       Platform  Nintendo      4.01      1.26      0.87         0.17
# 111       Fighting  Nintendo      4.41      1.04      1.39         0.22
#
#       Global_Sales  Critic_Score  Critic_Count User_Score  User_Count  \
# 49           11.35          97.0          73.0        8.9      2147.0
# 97            7.51          97.0          87.0        9.1      1854.0
# 517           2.82          97.0          70.0        9.3       747.0
# 233           4.60          96.0          80.0        8.9       968.0
# 1162          1.59          96.0          16.0        9.2       568.0
# 553           2.70          95.0          30.0        9.1       314.0
# 107           7.15          95.0          73.0          9      1658.0
# 166           5.47          93.0          24.0        8.3       108.0
# 260           4.32          93.0          83.0          9      1607.0
# 306           3.95          93.0          81.0          8      1958.0
# 39           12.84          93.0          81.0        8.9      1662.0
# 848           2.01          92.0          72.0        9.1      1130.0
# 4446          0.44          92.0          41.0        8.7       173.0
# 2275          0.91          92.0          59.0        8.9       950.0
# 2919          0.70          92.0          28.0          9        95.0
# 1474          1.33          92.0          60.0        8.8       279.0
# 6118          0.28          92.0          25.0        8.4       190.0
# 1081          1.68          92.0          44.0        9.1       200.0
# 136           6.31          92.0          61.0        8.6       439.0
# 111           7.07          92.0          38.0        9.1       568.0
#
#                 Developer Rating
# 49               Nintendo      E
# 97     Nintendo EAD Tokyo      E
# 517         Retro Studios      T
# 233              Nintendo      E
# 1162             Nintendo      T
# 553                Capcom      E
# 107              Nintendo      T
# 166   Intelligent Systems      E
# 260              Nintendo      E
# 306              Nintendo   E10+
# 39              Game Arts      T
# 848   Intelligent Systems      T
# 4446      Silicon Knights      M
# 2275        Monolith Soft      T
# 2919  Intelligent Systems      E
# 1474        Retro Studios      T
# 6118                 TOSE   E10+
# 1081             Nintendo      E
# 136              Nintendo      E
# 111              HAL Labs      T
